# %% [markdown]
# ## Візуалізація та робота з бібліотекою matplotlib

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\mykola\appdata\local\programs\python\python312\lib\site-packages (3.9.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mykola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mykola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mykola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mykola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\mykola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mykola\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\mykola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mykola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mykola\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\mykola\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# matplotlib inline

# %% [markdown]
# ### Імпорт необхідних бібліотеки

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Створення базових графіків

# %%
plt.plot([1, 5, 4, 10])
plt.show()

# %%
s = 50
rng = np.random.default_rng(seed=101)
x = rng.integers(0, 5, size=s, endpoint=True)
y = rng.integers(0, 100, size=s, endpoint=True)

print(f"""
X має {x.size} елементів, з них унікальні {np.unique(x)}
По Х: Максимум {x.max()}, Мінімум {x.min()}, Середнє значення: {x.mean()}


Y має {y.size} елементів, з них унікальних {np.unique(y).size} (не будемо виводити всі елементи)
По Y: Максимум {y.max()}, Мінімум {y.min()}, Середнє значення: {y.mean()}
""")
# Out:
# X має 50 елементів, з них унікальні [0 1 2 3 4 5]
# По Х: Максимум 5, Мінімум 0, Середнє значення: 2.46
#
#
# Y має 50 елементів, з них унікальних 36 (не будемо виводити всі елементи)
# По Y: Максимум 97, Мінімум 0, Середнє значення: 46.62

# %%
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Випадкові величини х та у')
plt.plot(y.mean().repeat(x.max()+2), "--")

plt.show()

# %%
print(np.histogram(y))
plt.hist(y)
plt.show()
# Out:
# (array([7, 3, 7, 3, 8, 6, 3, 3, 6, 4]), array([ 0. ,  9.7, 19.4, 29.1, 38.8, 48.5, 58.2, 67.9, 77.6, 87.3, 97. ]))

# %%
x = np.linspace(0, 5, 100)
ya = (6 - x)/4
yb = (4 - x)**2
yc = (3 - x)
yd = np.full_like(x, 1)

plt.plot(x, ya, label='y = (5 - x)/4')
plt.plot(x, yb, label='y = (3 - x)**2')
plt.plot(x, yc, label='y = 2 - x')
plt.plot(x, yd, label='y = 1')

plt.title('Візуалізація')
plt.xlabel('x')
plt.ylabel('y')

plt.show()
